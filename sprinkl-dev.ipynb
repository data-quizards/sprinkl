# %%
from glob import glob

import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep

import rasterio as rio
from rasterio.plot import show
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

import plotly.graph_objects as go

from rasterio.plot import plotting_extent

np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
landsat_bands1 = glob("Jan 2021/////B?*.png")
landsat_bands1.sort()

m = []
for i in landsat_bands1:
    with rio.open(i, 'r') as f:
        m.append(f.read(1))

# Data
arr_st1 = np.stack(m)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/rasterio/__init__.py:220: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix be returned.
#   s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
ep.plot_bands(arr_st1, cmap = 'gist_earth', figsize = (20, 12), cols = 6, cbar = False)
plt.show()

# %%
ep.plot_rgb(
    arr_st1,
    rgb=(4,3,2),
    stretch=False,
    str_clip=0.2,
    figsize=(10, 16),
    title="RGB Image with Stretch Applied",
)

plt.show()

# %%
colors = ['red', 'green', 'orange', 'blue',
          'black', 'purple', 'yellow',  'brown']

ep.hist(arr_st1, 
         colors = colors,
        title=[f'Band-{i}' for i in range(1, 9)], 
        cols=3, 
        alpha=0.5, 
        figsize = (12, 10)
        )

plt.show()
